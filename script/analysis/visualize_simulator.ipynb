# %%
from functions import read_log_from_file, parse_log, plot_gantt, get_subLog

# %%
log_path = "../../logs/simulation_20241030_105047.txt"
log_data = read_log_from_file(log_path)

# %%
# Use the function on the given log_data and parameters
task_id_input = 1
response_time_input = 21282000
sublog = get_subLog(task_id_input, response_time_input, log_data)

# Parse and plot the log data
task_data, releases, completions = parse_log(sublog)
plot_gantt(task_data, releases, completions)
# Out:
# 0
